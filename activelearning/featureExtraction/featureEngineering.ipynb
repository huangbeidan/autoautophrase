# %%
import sys
sys.path.insert(0, '/Users/beidan/RASHIP/nrde/autoautophrase/activelearning/featureExtraction')

# %%
from hierclusteringscipy import getdata
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
## get data
df = getdata()
df.head()
# Out:
#           0         1         2    3         4         5       6
# 0  0.016270  0.000000  0.000000  0.0  0.016431  0.000000  0.0000
# 1  0.001252  0.040816  0.001332  0.2  0.017581  0.238095  0.3000
# 2  0.037547  0.040816  0.001332  0.2  0.051594  0.309524  0.3000
# 3  0.002503  0.102041  0.091877  0.4  0.034012  0.440476  0.5500
# 4  0.001252  0.061224  0.002663  0.2  0.017581  0.190476  0.3334

# %%
fig = plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
fig.savefig('../../tmp/feature_correlation.png')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c5f64513fe3e> in <module>
# ----> 1 os.sys()
#
# TypeError: 'module' object is not callable
